# %%
print("hello")
# Out:
# hello

# %%
import numpy as np

# %%
def shuffle():
    hello = np.array([166546 ,2545 ,35 ,46,5487])
    # abc = [3,2,4,5,1]
    abc = np.random.permutation(5)
    new = hello[np.array([4,3,2,1,0])]
    print(abc)
    print(hello)
    print(new)

shuffle()
# Out:
# [0 4 2 3 1]
# [166546   2545     35     46   5487]
# [  5487     46     35   2545 166546]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

x = np.array([2,2,8,1,18,8,12,9,4,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,54,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#000000')

plt.show()
